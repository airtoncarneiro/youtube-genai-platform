# %% [markdown]
# # 30 — Fetch de canais
# Atualiza os canais dos vídeos encontrados e grava seus snapshots de métricas.

# %%
import json

from youtube_etl_genai.main import _get_api_key, _get_spark_session
from youtube_etl_genai.pipeline import fetch_channels_step

for name, default in [("ingestion_id", ""), ("catalog", "youtube_lakehouse"), ("secret_scope", "youtube_api_key"), ("secret_key", "api-key")]:
    dbutils.widgets.text(name, default)

spark = _get_spark_session()
result = fetch_channels_step(spark=spark, api_key=_get_api_key(spark, dbutils.widgets.get("secret_scope"), dbutils.widgets.get("secret_key")), ingestion_id=dbutils.widgets.get("ingestion_id"), catalog=dbutils.widgets.get("catalog"))
print(json.dumps(result))
