# %% [markdown]
# # Default Notebook

# %% [markdown]
# This notebook is executed using Databricks workflow as definied

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from quickstart_demo import main

main.get_taxis(spark).show(10)
